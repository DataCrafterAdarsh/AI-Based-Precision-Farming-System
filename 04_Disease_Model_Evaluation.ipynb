# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
model = load_model("../models/crop_disease_cnn_model.h5")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model = load_model("../models/crop_disease_cnn_model.h5")
#
# NameError: name 'load_model' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 model = load_model(
#       2     r"C:\Users\DELL\Downloads\crop_disease_model.h5"
#       3 )
#       5 model = load_model("../models/crop_disease_cnn_model.h5")
#
# File ~\anaconda3\Lib\site-packages\keras\src\saving\saving_api.py:196, in load_model(filepath, custom_objects, compile, safe_mode)
#     189     return saving_lib.load_model(
#     190         filepath,
#     191         custom_objects=custom_objects,
#     192         compile=compile,
#     193         safe_mode=safe_mode,
#     194     )
#     195 if str(filepath).endswith((".h5", ".hdf5")):
# --> 196     return legacy_h5_format.load_model_from_hdf5(
#     197         filepath,
#     198         custom_objects=custom_objects,
#     199         compile=compile,
#     200         safe_mode=safe_mode,
#     201     )
#     202 elif str(filepath).endswith(".keras"):
#     203     raise ValueError(
#     204         f"File not found: filepath={filepath}. "
#     205         "Please ensure the file is an accessible `.keras` "
#     206         "zip file."
#     207     )
#
# File ~\anaconda3\Lib\site-packages\keras\src\legacy\saving\legacy_h5_format.py:118, in load_model_from_hdf5(filepath, custom_objects, compile, safe_mode)
#     116 opened_new_file = not isinstance(filepath, h5py.File)
#     117 if opened_new_file:
# --> 118     f = h5py.File(filepath, mode="r")
#     119 else:
#     120     f = filepath
#
# File ~\anaconda3\Lib\site-packages\h5py\_hl\files.py:561, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     552     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     553                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     554                      alignment_threshold=alignment_threshold,
#     555                      alignment_interval=alignment_interval,
#     556                      meta_block_size=meta_block_size,
#     557                      **kwds)
#     558     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     559                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     560                      fs_page_size=fs_page_size)
# --> 561     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     563 if isinstance(libver, tuple):
#     564     self._libver = libver
#
# File ~\anaconda3\Lib\site-packages\h5py\_hl\files.py:235, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     233     if swmr and swmr_support:
#     234         flags |= h5f.ACC_SWMR_READ
# --> 235     fid = h5f.open(name, flags, fapl=fapl)
#     236 elif mode == 'r+':
#     237     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py\\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py\\h5f.pyx:102, in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to synchronously open file (unable to open file: name = 'C:\Users\DELL\Downloads\crop_disease_model.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\DELL\\Downloads'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '02_Image_Preprocessing.ipynb',
#  '03_CNN_Model.ipynb',
#  '04_Disease_Model_Evaluation.ipynb',
#  'Adarsh - Chrome.lnk',
#  'Adarsh_Mishra_Resume (1).docx',
#  'Adarsh_Mishra_Resume (1).pdf',
#  'Adarsh_Mishra_resume_.pdf',
#  'AIML 03_compressed.pdf',
#  'Anaconda3-2025.06-0-Windows-x86_64.exe',
#  'archive (1).zip',
#  'archive.zip',
#  'Assignment-CFG.pdf',
#  'Assignment-FA-RE.pdf',
#  'Assignment_PDA_TM.pdf',
#  'certificate.jpg',
#  'Covid-19 Dashboard.pbix',
#  'Crop_Disease_Yield_Project',
#  'desktop.ini',
#  'download.png',
#  'Ece 515 2023 ECE V Sem paper.pdf',
#  'ECE 515 End term Dec 22.pdf',
#  'ECE 515 Paper 2024.pdf',
#  'ECE 641 (1).pdf',
#  'ECE 641.pdf',
#  'Future_Trends_ML_Report_Aryan_Tripathi.docx',
#  'ilovepdf_pages-to-jpg (1)',
#  'ilovepdf_pages-to-jpg (1).zip',
#  'ilovepdf_pages-to-jpg.zip',
#  'New Doc 07-17-2025 22.51.pdf',
#  'New Doc 07-17-2025 22.51_1.pdf',
#  'New Doc 07-31-2025 23.30.pdf',
#  'New Doc 09-03-2025 19.28.pdf',
#  'New Doc 11-21-2025 19.14_3.pdf',
#  'New Doc 11-21-2025 19.14_3_page-0001.jpg',
#  'New Doc 11-22-2025 16.09_4.pdf',
#  'New Doc 11-22-2025 16.09_4_page-0001.jpg',
#  'node-v25.2.1-x64.msi',
#  'plant_disease_dataset',
#  'precision_farming_dashboard',
#  'python-3.14.0-amd64.exe',
#  'SB Offer letter - Adarsh.pdf',
#  'Seminar Report Template.pdf',
#  'sensor_data.csv',
#  'SHIATS_LOGO.png',
#  'task 1.pdf',
#  'task 2.pdf',
#  'task 3.pdf',
#  'task 4.pdf',
#  'task 5.pdf',
#  'task 6.pdf',
#  'task 7.pdf',
#  'Untitled.pdf',
#  'user.jpg.jpeg',
#  'VSCodeUserSetup-x64-1.106.2.exe',
#  'WhatsApp Image 2025-11-21 at 16.08.09 (1).jpeg',
#  'WhatsApp Image 2025-11-21 at 16.08.09.jpeg',
#  'WhatsApp Image 2025-12-05 at 21.52.11 (1).jpeg',
#  'WhatsApp Image 2025-12-05 at 21.52.11.jpeg',
#  'WhatsApp Image 2025-12-09 at 04.23.01.jpeg',
#  'WhatsApp Image 2025-12-09 at 12.17.44.jpeg',
#  'WhatsApp Image 2025-12-09 at 15.51.49.jpeg',
#  'WhatsApp Image 2025-12-09 at 16.47.18.jpeg',
#  'WhatsApp Image 2025-12-09 at 16.47.19.jpeg',
#  'WhatsApp Image 2025-12-09 at 16.47.51.jpeg',
#  'WhatsApp Image 2025-12-09 at 16.47.52.jpeg']

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\DELL\\Downloads'

# %%
model.save("crop_disease_model.h5")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 model.save("crop_disease_model.h5")
#
# NameError: name 'model' is not defined

# %%
DATASET_PATH = r"C:\Users\DELL\Downloads\plant_disease_dataset\Train"

# %%
img_size = 128
batch_size = 32

datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_data = datagen.flow_from_directory(
    DATASET_PATH,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode="categorical",
    subset="training"
)

val_data = datagen.flow_from_directory(
    DATASET_PATH,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode="categorical",
    subset="validation"
)
# Out:
# Found 3276 images belonging to 4 classes.
# Found 817 images belonging to 4 classes.

# %%
model = Sequential([
    Conv2D(32, (3,3), activation="relu", input_shape=(img_size, img_size, 3)),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation="relu"),
    MaxPooling2D(2,2),

    Flatten(),
    Dense(128, activation="relu"),
    Dense(train_data.num_classes, activation="softmax")
])
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=5
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 history = model.fit(
#       2     train_data,
#       3     validation_data=val_data,
#       4     epochs=5
#       5 )
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\anaconda3\Lib\site-packages\keras\src\trainers\trainer.py:1058, in Trainer._assert_compile_called(self, method_name)
#    1056 else:
#    1057     msg += f"calling `{method_name}()`."
# -> 1058 raise ValueError(msg)
#
# ValueError: You must call `compile()` before using the model.

# %%
model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=5
)
# Out:
# Epoch 1/5
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 56s 492ms/step - accuracy: 0.6923 - loss: 0.7824 - val_accuracy: 0.8250 - val_loss: 0.4224
# Epoch 2/5
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 44s 429ms/step - accuracy: 0.8968 - loss: 0.2727 - val_accuracy: 0.9143 - val_loss: 0.2501
# Epoch 3/5
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 45s 436ms/step - accuracy: 0.9435 - loss: 0.1592 - val_accuracy: 0.9327 - val_loss: 0.1474
# Epoch 4/5
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 45s 432ms/step - accuracy: 0.9689 - loss: 0.0965 - val_accuracy: 0.9523 - val_loss: 0.1446
# Epoch 5/5
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 44s 430ms/step - accuracy: 0.9847 - loss: 0.0529 - val_accuracy: 0.9584 - val_loss: 0.1135

# %%
model.save("crop_disease_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '02_Image_Preprocessing.ipynb',
#  '03_CNN_Model.ipynb',
#  '04_Disease_Model_Evaluation.ipynb',
#  'Adarsh - Chrome.lnk',
#  'Adarsh_Mishra_Resume (1).docx',
#  'Adarsh_Mishra_Resume (1).pdf',
#  'Adarsh_Mishra_resume_.pdf',
#  'AIML 03_compressed.pdf',
#  'Anaconda3-2025.06-0-Windows-x86_64.exe',
#  'archive (1).zip',
#  'archive.zip',
#  'Assignment-CFG.pdf',
#  'Assignment-FA-RE.pdf',
#  'Assignment_PDA_TM.pdf',
#  'certificate.jpg',
#  'Covid-19 Dashboard.pbix',
#  'crop_disease_model.h5',
#  'Crop_Disease_Yield_Project',
#  'desktop.ini',
#  'download.png',
#  'Ece 515 2023 ECE V Sem paper.pdf',
#  'ECE 515 End term Dec 22.pdf',
#  'ECE 515 Paper 2024.pdf',
#  'ECE 641 (1).pdf',
#  'ECE 641.pdf',
#  'Future_Trends_ML_Report_Aryan_Tripathi.docx',
#  'ilovepdf_pages-to-jpg (1)',
#  'ilovepdf_pages-to-jpg (1).zip',
#  'ilovepdf_pages-to-jpg.zip',
#  'New Doc 07-17-2025 22.51.pdf',
#  'New Doc 07-17-2025 22.51_1.pdf',
#  'New Doc 07-31-2025 23.30.pdf',
#  'New Doc 09-03-2025 19.28.pdf',
#  'New Doc 11-21-2025 19.14_3.pdf',
#  'New Doc 11-21-2025 19.14_3_page-0001.jpg',
#  'New Doc 11-22-2025 16.09_4.pdf',
#  'New Doc 11-22-2025 16.09_4_page-0001.jpg',
#  'node-v25.2.1-x64.msi',
#  'plant_disease_dataset',
#  'precision_farming_dashboard',
#  'python-3.14.0-amd64.exe',
#  'SB Offer letter - Adarsh.pdf',
#  'Seminar Report Template.pdf',
#  'sensor_data.csv',
#  'SHIATS_LOGO.png',
#  'task 1.pdf',
#  'task 2.pdf',
#  'task 3.pdf',
#  'task 4.pdf',
#  'task 5.pdf',
#  'task 6.pdf',
#  'task 7.pdf',
#  'Untitled.pdf',
#  'user.jpg.jpeg',
#  'VSCodeUserSetup-x64-1.106.2.exe',
#  'WhatsApp Image 2025-11-21 at 16.08.09 (1).jpeg',
#  'WhatsApp Image 2025-11-21 at 16.08.09.jpeg',
#  'WhatsApp Image 2025-12-05 at 21.52.11 (1).jpeg',
#  'WhatsApp Image 2025-12-05 at 21.52.11.jpeg',
#  'WhatsApp Image 2025-12-09 at 04.23.01.jpeg',
#  'WhatsApp Image 2025-12-09 at 12.17.44.jpeg',
#  'WhatsApp Image 2025-12-09 at 15.51.49.jpeg',
#  'WhatsApp Image 2025-12-09 at 16.47.18.jpeg',
#  'WhatsApp Image 2025-12-09 at 16.47.19.jpeg',
#  'WhatsApp Image 2025-12-09 at 16.47.51.jpeg',
#  'WhatsApp Image 2025-12-09 at 16.47.52.jpeg']
